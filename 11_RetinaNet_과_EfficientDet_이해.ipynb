# %% [markdown]
# <a href="https://colab.research.google.com/github/WoogiWooks/DLCV_New/blob/main/11_RetinaNet_%EA%B3%BC_EfficientDet_%EC%9D%B4%ED%95%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **RetinaNet**
# * One-Stage Detection 보다 수행시간은 느리지만 **작은 Object에 대한 Detection** 능력이 뛰어남
# * Focal Loss 개념과 FPN 구조의 도입
# * FPN 구조의 가능성을 보여줌

# %% [markdown]
# ## **Focal Loss**
# * 분류에서 성능 지표인 Cross-Entropy 의 변형

# %% [markdown]
# ![K-012.png](data:image/png;base64,...)

# %% [markdown]
# ![K-013.png](data:image/png;base64,...)

# %% [markdown]
# ![K-014.png](data:image/png;base64,...)

# %% [markdown]
# ![K-015.png](data:image/png;base64,...)

# %% [markdown]
# ![K-016.png](data:image/png;base64,...)

# %% [markdown]
# ![K-017.png](data:image/png;base64,...)

# %% [markdown]
# ## **Feature Pyramid Network (FPN)**
# * 서로 다른 크기의 Object들을 효과적으로 Detection하기 위한 방법

# %% [markdown]
# ![K-013.png](data:image/png;base64,...)

# %% [markdown]
# ![K-010.png](data:image/png;base64,...)

# %% [markdown]
# # **EfficientDet**
# * 적은 파라미터 및 연산 수에 비해 타 모델 대비 높은 예측 성능
# * EfficientNet Backbone - Compound Scaling
# * Compund Scaling to Backbone/Neck/Head
# * BiFPN - Weighted Feature Fusion

# %% [markdown]
# ## **EfficientNet Backbone - Compound Scaling**

# %% [markdown]
# ![K-014.png](data:image/png;base64,...)

# %% [markdown]
# ![K-016.png](data:image/png;base64,...)

# %% [markdown]
# ![K-017.png](data:image/png;base64,...)

# %% [markdown]
# ![K-018.png](data:image/png;base64,...)

# %% [markdown]
# ## **EfficientDet Compound Scaling - Spread to All of Network**

# %% [markdown]
# ![K-021.png](data:image/png;base64,...)

# %% [markdown]
# ![K-019.png](data:image/png;base64,...)

# %% [markdown]
# ![K-020.png](data:image/png;base64,...)

# %% [markdown]
# ## **BiFPN**

# %% [markdown]
# ![K-010.png](data:image/png;base64,...)

# %% [markdown]
# ![K-012.png](data:image/png;base64,...)

# %% [markdown]
# ![K-013.png](data:image/png;base64,...)
